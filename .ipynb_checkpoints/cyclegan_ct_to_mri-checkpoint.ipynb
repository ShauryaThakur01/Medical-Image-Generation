# %%
# !pip install git+https://github.com/tensorflow/examples.git
# Out:
# Collecting git+https://github.com/tensorflow/examples.git
#   Cloning https://github.com/tensorflow/examples.git to c:\users\shaur\appdata\local\temp\pip-req-build-mzcuansc
#   Resolved https://github.com/tensorflow/examples.git to commit fed63294c10c71b7da028e0e75de9ff68ac56d17
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: absl-py in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-examples==0.1741282361.1454860421494433302046033067432040489300359736599) (2.1.0)
# Requirement already satisfied: six in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-examples==0.1741282361.1454860421494433302046033067432040489300359736599) (1.16.0)
# Building wheels for collected packages: tensorflow-examples
#   Building wheel for tensorflow-examples (setup.py): started
#   Building wheel for tensorflow-examples (setup.py): finished with status 'done'
#   Created wheel for tensorflow-examples: filename=tensorflow_examples-0.1741282361.1454860421494433302046033067432040489300359736599-py3-none-any.whl size=303860 sha256=74d42cddb401e856d3dbd1a9ace011ebe4d85800077839a9b6b516000f2e16eb
#   Stored in directory: C:\Users\shaur\AppData\Local\Temp\pip-ephem-wheel-cache-0ii2aik0\wheels\91\9b\e8\6ae2ecc930bd726c578e35b313e987a687bc5ce03c3a42c2d5
# Successfully built tensorflow-examples
# Installing collected packages: tensorflow-examples
# Successfully installed tensorflow-examples-0.1741282361.1454860421494433302046033067432040489300359736599
#   Running command git clone --filter=blob:none --quiet https://github.com/tensorflow/examples.git 'C:\Users\shaur\AppData\Local\Temp\pip-req-build-mzcuansc'

# %%
# !pip install tensorflow_datasets
# Out:
# Collecting tensorflow_datasets
#   Downloading tensorflow_datasets-4.9.7-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: absl-py in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (2.1.0)
# Requirement already satisfied: click in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (8.1.7)
# Requirement already satisfied: dm-tree in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (0.1.8)
# Collecting immutabledict (from tensorflow_datasets)
#   Downloading immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (1.26.4)
# Collecting promise (from tensorflow_datasets)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: protobuf>=3.20 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (3.20.3)
# Requirement already satisfied: psutil in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (5.9.0)
# Requirement already satisfied: pyarrow in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (14.0.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (2.31.0)
# Collecting simple-parsing (from tensorflow_datasets)
#   Downloading simple_parsing-0.1.7-py3-none-any.whl.metadata (7.3 kB)
# Collecting tensorflow-metadata (from tensorflow_datasets)
#   Downloading tensorflow_metadata-1.16.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: termcolor in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (2.4.0)
# Requirement already satisfied: toml in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (0.10.2)
# Requirement already satisfied: tqdm in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (4.65.0)
# Requirement already satisfied: wrapt in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow_datasets) (1.14.1)
# Collecting etils>=1.9.1 (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets)
#   Downloading etils-1.12.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting einops (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: fsspec in c:\users\shaur\anaconda3\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (2023.10.0)
# Requirement already satisfied: importlib_resources in c:\users\shaur\anaconda3\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in c:\users\shaur\anaconda3\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (4.12.2)
# Requirement already satisfied: zipp in c:\users\shaur\anaconda3\lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow_datasets) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaur\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaur\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaur\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaur\anaconda3\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\shaur\anaconda3\lib\site-packages (from click->tensorflow_datasets) (0.4.6)
# Requirement already satisfied: six in c:\users\shaur\anaconda3\lib\site-packages (from promise->tensorflow_datasets) (1.16.0)
# Collecting docstring-parser<1.0,>=0.15 (from simple-parsing->tensorflow_datasets)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting googleapis-common-protos<2,>=1.56.4 (from tensorflow-metadata->tensorflow_datasets)
#   Downloading googleapis_common_protos-1.69.1-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf>=3.20 (from tensorflow_datasets)
#   Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Downloading tensorflow_datasets-4.9.7-py3-none-any.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    - -------------------------------------- 0.1/5.3 MB 4.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.7/5.3 MB 8.6 MB/s eta 0:00:01
#    ------ --------------------------------- 0.9/5.3 MB 6.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.0/5.3 MB 6.0 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.3 MB 5.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.3 MB 5.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.3 MB 5.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.3 MB 5.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.1/5.3 MB 5.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.3/5.3 MB 3.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.3/5.3 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 2.5/5.3 MB 4.5 MB/s eta 0:00:01
#    -------------------- ------------------- 2.7/5.3 MB 4.5 MB/s eta 0:00:01
#    -------------------- ------------------- 2.7/5.3 MB 4.5 MB/s eta 0:00:01
#    -------------------- ------------------- 2.7/5.3 MB 4.5 MB/s eta 0:00:01
#    -------------------- ------------------- 2.8/5.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.0/5.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.4/5.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.8/5.3 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.0/5.3 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.1/5.3 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.2/5.3 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.2/5.3 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.2/5.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.6/5.3 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.1/5.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  5.2/5.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  5.3/5.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 4.1 MB/s eta 0:00:00
# Downloading etils-1.12.1-py3-none-any.whl (167 kB)
#    ---------------------------------------- 0.0/167.6 kB ? eta -:--:--
#    ---------------------------------------- 167.6/167.6 kB 5.1 MB/s eta 0:00:00
# Downloading immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Downloading simple_parsing-0.1.7-py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.8 kB ? eta -:--:--
#    ---------------------------------------- 112.8/112.8 kB 6.4 MB/s eta 0:00:00
# Downloading tensorflow_metadata-1.16.1-py3-none-any.whl (28 kB)
# Downloading protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
#    ---------------------------------------- 0.0/434.5 kB ? eta -:--:--
#    --------------------------------------- 434.5/434.5 kB 13.7 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading googleapis_common_protos-1.69.1-py2.py3-none-any.whl (293 kB)
#    ---------------------------------------- 0.0/293.2 kB ? eta -:--:--
#    ---------------------------------------- 293.2/293.2 kB 8.8 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.4 kB ? eta -:--:--
#    ---------------------------------------- 64.4/64.4 kB 3.6 MB/s eta 0:00:00
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21545 sha256=a7e495ddf82ad52fcd80ba468dc497146e56c1d544e9aada206b8ec005932769
#   Stored in directory: c:\users\shaur\appdata\local\pip\cache\wheels\90\74\b1\9b54c896b8d9409e9268329d4d45ede8a8040abe91c8879932
# Successfully built promise
# Installing collected packages: protobuf, promise, immutabledict, etils, einops, docstring-parser, simple-parsing, googleapis-common-protos, tensorflow-metadata, tensorflow_datasets
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed docstring-parser-0.16 einops-0.8.1 etils-1.12.1 googleapis-common-protos-1.69.1 immutabledict-4.2.1 promise-2.3 protobuf-5.29.3 simple-parsing-0.1.7 tensorflow-metadata-1.16.1 tensorflow_datasets-4.9.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.30.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.3 which is incompatible.
# tensorflow-intel 2.16.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_examples.models.pix2pix import pix2pix

import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

AUTOTUNE = tf.data.AUTOTUNE

print(AUTOTUNE)
# Out:
# -1

# %%
BUFFER_SIZE = 1000
BATCH_SIZE = 1
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
def random_crop(image):
  # Remove the batch dimension
  image = tf.squeeze(image, axis=0)

  cropped_image = tf.image.random_crop(
      image, size=[IMG_HEIGHT, IMG_WIDTH, 3])

  # Add the batch dimension back
  cropped_image = tf.expand_dims(cropped_image, axis=0)

  return cropped_image

# normalizing the images to [-1, 1]
def normalize(image):
  image = tf.cast(image, tf.float32)
  image = (image / 127.5) - 1
  return image

def random_jitter(image):
  # Ensure the image has 3 color channels (RGB)
  if image.shape[-1] != 3:
    image = tf.image.grayscale_to_rgb(image)

  # resizing to 286 x 286 x 3
  image = tf.image.resize(image, [286, 286],
                          method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  # randomly cropping to 256 x 256 x 3
  image = random_crop(image)

  # random mirroring
  image = tf.image.random_flip_left_right(image)

  return image

def preprocess_image_train(image):
  image = random_jitter(image)
  image = normalize(image)
  return image

def preprocess_image_test(image):
  image = normalize(image)
  return image

# %%
def load_custom_dataset(data_dir, image_size=(IMG_WIDTH, IMG_HEIGHT), batch_size=BATCH_SIZE, buffer_size=BUFFER_SIZE):
    """
    Load a custom dataset from specified directories and apply preprocessing steps.

    Args:
        data_dir (str): The root directory containing 'trainA', 'trainB', 'testA', and 'testB' folders.
        image_size (tuple): The size to resize the images to, e.g., (256, 256).
        batch_size (int): The batch size for the dataset.
        buffer_size (int): The buffer size for shuffling.

    Returns:
        train_horses (tf.data.Dataset): Dataset for 'trainA' images.
        train_zebras (tf.data.Dataset): Dataset for 'trainB' images.
        test_horses (tf.data.Dataset): Dataset for 'testA' images.
        test_zebras (tf.data.Dataset): Dataset for 'testB' images.
    """
    # Define data directories
    trainA_dir = os.path.join(data_dir, 'trainA')
    trainB_dir = os.path.join(data_dir, 'trainB')
    testA_dir = os.path.join(data_dir, 'testA')
    testB_dir = os.path.join(data_dir, 'testB')

    # Define image preprocessing functions (preprocess_image_train and preprocess_image_test)
    # Make sure to define these functions according to your specific requirements.


    train_ct = tf.keras.utils.image_dataset_from_directory(
        trainA_dir,
        label_mode=None,
        image_size=image_size,
        batch_size=batch_size,
        shuffle=True
    ).cache().map(preprocess_image_train, num_parallel_calls=AUTOTUNE).shuffle(buffer_size).batch(batch_size)

    train_mri = tf.keras.utils.image_dataset_from_directory(
        trainB_dir,
        label_mode=None,
        image_size=image_size,
        batch_size=batch_size,
        shuffle=True
    ).cache().map(preprocess_image_train, num_parallel_calls=AUTOTUNE).shuffle(buffer_size).batch(batch_size)

    test_ct = tf.keras.utils.image_dataset_from_directory(
        testA_dir,
        label_mode=None,
        image_size=image_size,
        batch_size=batch_size,
    ).map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(buffer_size).batch(batch_size)

    test_mri = tf.keras.utils.image_dataset_from_directory(
        testB_dir,
        label_mode=None,
        image_size=image_size,
        batch_size=batch_size,
    ).map(preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(buffer_size).batch(batch_size)

    return train_ct, train_mri, test_ct, test_mri

# %%
data_dir=r'C:\Users\shaur\Tumor+CycleGan\Dataset\cyclegan_dataset\ct_mri_unpaired_dataset\images'
train_ct, train_mri, test_ct, test_mri=load_custom_dataset(data_dir)
# Out:
# Found 1742 files.
# Found 1744 files.
# Found 744 files.
# Found 744 files.

# %%
def remove_batch_dimension(image):
    # Remove the first dimension
    return image[0]

# %%
train_ct = train_ct.map(remove_batch_dimension)
train_mri = train_mri.map(remove_batch_dimension)
test_ct = test_ct.map(remove_batch_dimension)
test_mri = test_mri.map(remove_batch_dimension)

# %%
sample_ct = next(iter(train_ct))
sample_mri = next(iter(train_mri))
# sample_ct_jittered=sample_ct[0]
# sample_mri_jittered=sample_mri[0]

# %%
sample_ct.shape
# Out:
# TensorShape([1, 256, 256, 3])

# %%
OUTPUT_CHANNELS = 3

generator_g = pix2pix.unet_generator(OUTPUT_CHANNELS, norm_type='instancenorm')
generator_f = pix2pix.unet_generator(OUTPUT_CHANNELS, norm_type='instancenorm')

discriminator_x = pix2pix.discriminator(norm_type='instancenorm', target=False)
discriminator_y = pix2pix.discriminator(norm_type='instancenorm', target=False)
# Out:
# WARNING:tensorflow:From C:\Users\shaur\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
to_mri = generator_g(sample_ct)
to_ct = generator_f(sample_mri)
plt.figure(figsize=(8, 8))
contrast = 8

imgs = [sample_ct, to_mri, sample_mri, to_ct]
title = ['CT', 'To MRI', 'MRI', 'To CT']

for i in range(len(imgs)):
  plt.subplot(2, 2, i+1)
  plt.title(title[i])
  if i % 2 == 0:
    plt.imshow(imgs[i][0] * 0.5 + 0.5)
  else:
    plt.imshow(imgs[i][0] * 0.5 * contrast + 0.5)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(8, 8))

plt.subplot(121)
plt.title('Is a real MRI?')
plt.imshow(discriminator_y(sample_mri)[0, ..., -1], cmap='RdBu_r')

plt.subplot(122)
plt.title('Is a real CT?')
plt.imshow(discriminator_x(sample_ct)[0, ..., -1], cmap='RdBu_r')

plt.show()

# %%
LAMBDA = 10

# %%
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real, generated):
  real_loss = loss_obj(tf.ones_like(real), real)

  generated_loss = loss_obj(tf.zeros_like(generated), generated)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss * 0.5

# %%
def generator_loss(generated):
  return loss_obj(tf.ones_like(generated), generated)

# %%
def calc_cycle_loss(real_image, cycled_image):
  loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

  return LAMBDA * loss1

# %%
def identity_loss(real_image, same_image):
  loss = tf.reduce_mean(tf.abs(real_image - same_image))
  return LAMBDA * 0.5 * loss

# %%
# !pip install tf_keras
# Out:
# Requirement already satisfied: tf_keras in c:\users\shaur\anaconda3\lib\site-packages (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in c:\users\shaur\anaconda3\lib\site-packages (from tf_keras) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow<2.17,>=2.16->tf_keras) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.3.0)
# Requirement already satisfied: packaging in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (23.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras)
#   Downloading protobuf-4.25.6-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.0.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shaur\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.41.2)
# Requirement already satisfied: rich in c:\users\shaur\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\shaur\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.0.7)
# Requirement already satisfied: dm-tree in c:\users\shaur\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shaur\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\shaur\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shaur\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shaur\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.1.0)
# Downloading protobuf-4.25.6-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/413.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/413.4 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/413.4 kB 259.2 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/413.4 kB 245.8 kB/s eta 0:00:02
#    ---------- --------------------------- 112.6/413.4 kB 544.7 kB/s eta 0:00:01
#    --------------------------- ------------ 286.7/413.4 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 413.4/413.4 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
# Successfully installed protobuf-4.25.6

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
import tensorflow as tf

# %%
generator_g_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
generator_f_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

discriminator_x_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_y_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\shaur\anaconda3\lib\site-packages (2.16.1)
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Downloading tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.62.1)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading keras-3.9.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Collecting h5py>=3.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading h5py-3.13.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading ml_dtypes-0.4.1-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shaur\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\shaur\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\shaur\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.7)
# Collecting optree (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading optree-0.14.1-cp311-cp311-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#      ------------------------------- ------ 41.0/50.1 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 50.1/50.1 kB 847.4 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaur\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shaur\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shaur\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\shaur\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shaur\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shaur\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.18.0-cp311-cp311-win_amd64.whl (7.5 kB)
# Downloading tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl (390.2 MB)
#    ---------------------------------------- 0.0/390.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/390.2 MB 5.9 MB/s eta 0:01:06
#    ---------------------------------------- 0.6/390.2 MB 8.0 MB/s eta 0:00:49
#    ---------------------------------------- 0.9/390.2 MB 7.0 MB/s eta 0:00:56
#    ---------------------------------------- 1.1/390.2 MB 6.1 MB/s eta 0:01:04
#    ---------------------------------------- 1.3/390.2 MB 5.7 MB/s eta 0:01:09
#    ---------------------------------------- 1.4/390.2 MB 5.7 MB/s eta 0:01:09
#    ---------------------------------------- 1.6/390.2 MB 5.1 MB/s eta 0:01:16
#    ---------------------------------------- 1.8/390.2 MB 5.0 MB/s eta 0:01:18
#    ---------------------------------------- 2.0/390.2 MB 4.8 MB/s eta 0:01:21
#    ---------------------------------------- 2.2/390.2 MB 4.7 MB/s eta 0:01:22
#    ---------------------------------------- 2.3/390.2 MB 4.6 MB/s eta 0:01:24
#    ---------------------------------------- 2.5/390.2 MB 4.6 MB/s eta 0:01:25
#    ---------------------------------------- 2.7/390.2 MB 4.5 MB/s eta 0:01:26
#    ---------------------------------------- 2.9/390.2 MB 4.5 MB/s eta 0:01:27
#    ---------------------------------------- 3.1/390.2 MB 4.5 MB/s eta 0:01:27
#    ---------------------------------------- 3.2/390.2 MB 4.4 MB/s eta 0:01:28
#    ---------------------------------------- 3.4/390.2 MB 4.5 MB/s eta 0:01:27
#    ---------------------------------------- 3.6/390.2 MB 4.4 MB/s eta 0:01:29
#    ---------------------------------------- 3.8/390.2 MB 4.3 MB/s eta 0:01:30
#    ---------------------------------------- 4.0/390.2 MB 4.3 MB/s eta 0:01:30
#    ---------------------------------------- 4.2/390.2 MB 4.3 MB/s eta 0:01:31
#    ---------------------------------------- 4.3/390.2 MB 4.3 MB/s eta 0:01:31
#    ---------------------------------------- 4.5/390.2 MB 4.2 MB/s eta 0:01:31
#    ---------------------------------------- 4.7/390.2 MB 4.2 MB/s eta 0:01:31
#     ---------------------------------------
390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  384.8/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  385.0/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  385.1/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  385.3/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  385.5/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  385.7/390.2 MB 4.1 MB/s eta 0:00:02
#    ---------------------------------------  385.9/390.2 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------------  386.1/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  386.2/390.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  386.4/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  386.6/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  386.8/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.0/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.3/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.5/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.7/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  387.9/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  388.0/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  388.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  388.4/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  388.6/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  388.8/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.0/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.1/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.3/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.5/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.7/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  389.9/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.1/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  390.2/390.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 390.2/390.2 MB 2.8 MB/s eta 0:00:00
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading h5py-3.13.0-cp311-cp311-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.6/3.0 MB 12.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.0 MB 9.6 MB/s eta 0:00:01
#    ------------ --------------------------- 0.9/3.0 MB 7.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.1/3.0 MB 6.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.3/3.0 MB 5.9 MB/s eta 0:00:01
#    -------------------- ------------------- 1.5/3.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.7/3.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.9/3.0 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 2.0/3.0 MB 5.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.2/3.0 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/3.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.6/3.0 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 2.8/3.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  2.9/3.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 4.3 MB/s eta 0:00:00
# Downloading keras-3.9.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ----------- ---------------------------- 0.4/1.3 MB 12.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.3 MB 7.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 0.9/1.3 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.1/1.3 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.3 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.3 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp311-cp311-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.7 kB ? eta -:--:--
#    ---------------------------------------- 126.7/126.7 kB 3.8 MB/s eta 0:00:00
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 15.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/5.5 MB 8.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.9/5.5 MB 6.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.0/5.5 MB 6.0 MB/s eta 0:00:01
#    --------- ------------------------------ 1.2/5.5 MB 5.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.5 MB 5.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.6/5.5 MB 5.1 MB/s eta 0:00:01
#    ------------ --------------------------- 1.8/5.5 MB 4.9 MB/s eta 0:00:01
#    -------------- ------------------------- 2.0/5.5 MB 4.8 MB/s eta 0:00:01
#    --------------- ------------------------ 2.2/5.5 MB 4.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.3/5.5 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 2.5/5.5 MB 4.5 MB/s eta 0:00:01
#    ------------------- -------------------- 2.7/5.5 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.9/5.5 MB 4.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 4.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.3/5.5 MB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 3.6/5.5 MB 4.3 MB/s eta 0:00:01
#    --------------------------- ------------ 3.8/5.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.0/5.5 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 4.3/5.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 5.1/5.5 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 4.0 MB/s eta 0:00:00
# Downloading optree-0.14.1-cp311-cp311-win_amd64.whl (305 kB)
#    ---------------------------------------- 0.0/305.8 kB ? eta -:--:--
#    ---------------------------------------- 305.8/305.8 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, optree, ml-dtypes, h5py, tensorboard, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 24.3.7
#     Uninstalling flatbuffers-24.3.7:
#       Successfully uninstalled flatbuffers-24.3.7
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.3.2
#     Uninstalling ml-dtypes-0.3.2:
#       Successfully uninstalled ml-dtypes-0.3.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.10.0
#     Uninstalling h5py-3.10.0:
#       Successfully uninstalled h5py-3.10.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: keras
#     Found existing installation: keras 3.0.5
#     Uninstalling keras-3.0.5:
#       Successfully uninstalled keras-3.0.5
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.16.1
#     Uninstalling tensorflow-intel-2.16.1:
#       Successfully uninstalled tensorflow-intel-2.16.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.1
#     Uninstalling tensorflow-2.16.1:
#       Successfully uninstalled tensorflow-2.16.1
# Successfully installed flatbuffers-25.2.10 h5py-3.13.0 keras-3.9.0 ml-dtypes-0.4.1 optree-0.14.1 tensorboard-2.18.0 tensorflow-2.18.0 tensorflow-intel-2.18.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\shaur\anaconda3\Lib\site-packages\~l_dtypes'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\shaur\anaconda3\Lib\site-packages\~5py'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\shaur\anaconda3\Lib\site-packages\~ensorflow'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.16.0 requires tensorflow<2.17,>=2.16, but you have tensorflow 2.18.0 which is incompatible.

# %%
checkpoint_path = r"C:\Users\shaur\Tumor+CycleGan"

ckpt = tf.train.Checkpoint(generator_g=generator_g,
                           generator_f=generator_f,
                           discriminator_x=discriminator_x,
                           discriminator_y=discriminator_y,
                           generator_g_optimizer=generator_g_optimizer,
                           generator_f_optimizer=generator_f_optimizer,
                           discriminator_x_optimizer=discriminator_x_optimizer,
                           discriminator_y_optimizer=discriminator_y_optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
EPOCHS = 15

# %%
def generate_images(model, test_input):
  prediction = model(test_input)

  plt.figure(figsize=(12, 12))

  display_list = [test_input[0], prediction[0]]
  title = ['Input Image', 'Predicted Image']

  for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
@tf.function
def train_step(real_x, real_y):
  # persistent is set to True because the tape is used more than
  # once to calculate the gradients.
  with tf.GradientTape(persistent=True) as tape:
    # Generator G translates X -> Y
    # Generator F translates Y -> X.

    fake_y = generator_g(real_x, training=True)
    cycled_x = generator_f(fake_y, training=True)

    fake_x = generator_f(real_y, training=True)
    cycled_y = generator_g(fake_x, training=True)

    # same_x and same_y are used for identity loss.
    same_x = generator_f(real_x, training=True)
    same_y = generator_g(real_y, training=True)

    disc_real_x = discriminator_x(real_x, training=True)
    disc_real_y = discriminator_y(real_y, training=True)

    disc_fake_x = discriminator_x(fake_x, training=True)
    disc_fake_y = discriminator_y(fake_y, training=True)

    # calculate the loss
    gen_g_loss = generator_loss(disc_fake_y)
    gen_f_loss = generator_loss(disc_fake_x)

    total_cycle_loss = calc_cycle_loss(real_x, cycled_x) + calc_cycle_loss(real_y, cycled_y)

    # Total generator loss = adversarial loss + cycle loss
    total_gen_g_loss = gen_g_loss + total_cycle_loss + identity_loss(real_y, same_y)
    total_gen_f_loss = gen_f_loss + total_cycle_loss + identity_loss(real_x, same_x)

    disc_x_loss = discriminator_loss(disc_real_x, disc_fake_x)
    disc_y_loss = discriminator_loss(disc_real_y, disc_fake_y)

  # Calculate the gradients for generator and discriminator
  generator_g_gradients = tape.gradient(total_gen_g_loss,
                                        generator_g.trainable_variables)
  generator_f_gradients = tape.gradient(total_gen_f_loss,
                                        generator_f.trainable_variables)

  discriminator_x_gradients = tape.gradient(disc_x_loss,
                                            discriminator_x.trainable_variables)
  discriminator_y_gradients = tape.gradient(disc_y_loss,
                                            discriminator_y.trainable_variables)

  # Apply the gradients to the optimizer
  generator_g_optimizer.apply_gradients(zip(generator_g_gradients,
                                            generator_g.trainable_variables))

  generator_f_optimizer.apply_gradients(zip(generator_f_gradients,
                                            generator_f.trainable_variables))

  discriminator_x_optimizer.apply_gradients(zip(discriminator_x_gradients,
                                                discriminator_x.trainable_variables))

  discriminator_y_optimizer.apply_gradients(zip(discriminator_y_gradients,
                                                discriminator_y.trainable_variables))

# %%
from tqdm import tqdm

# MSE loss function
def mse_loss(target, predicted):
    return tf.reduce_mean(tf.square(target - predicted))

# Model training
for epoch in range(EPOCHS):
    start = time.time()

    n = 0
    mse_loss_values = []  # To store MSE loss values for each iteration

    progress_bar = tqdm(tf.data.Dataset.zip((train_ct, train_mri)), desc=f'Epoch {epoch + 1}', total=len(train_ct))

    for image_x, image_y in progress_bar:
        train_step(image_x, image_y)
        mse_loss_value = mse_loss(image_y, generator_f(image_x))
        mse_loss_values.append(mse_loss_value.numpy())

        if n % 10 == 0:
            progress_bar.set_postfix({'Elapsed Time': time.time() - start, 'MSE Loss': mse_loss_value.numpy()})
        n += 1

    clear_output(wait=True)

    generate_images(generator_f, sample_ct)

    # Calculate and print the mean MSE loss for the epoch
    mean_mse_loss = sum(mse_loss_values) / len(mse_loss_values)
    print(f'Mean MSE Loss for Epoch {epoch + 1}: {mean_mse_loss}')

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print('Saving checkpoint for epoch {} at {}'.format(epoch + 1, ckpt_save_path))

    print('Time taken for epoch {} is {} sec\n'.format(epoch + 1, time.time() - start))
# Out:
# Mean MSE Loss for Epoch 15: 0.5152675557041358
# Saving checkpoint for epoch 15 at C:\Users\shaur\Tumor+CycleGan\ckpt-3
# Time taken for epoch 15 is 2157.5097663402557 sec

# %%
# Model Prediction: Generate MRI images for given CT images
for ct_image in test_ct.take(5):
    # Generate MRI image from CT using generator_f
    generated_mri = generator_f(ct_image, training=False)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.title('Original CT')
    plt.imshow((ct_image[0] + 1) / 2.0)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title('Generated MRI')
    plt.imshow((generated_mri[0] + 1) / 2.0)
    plt.axis('off')

    plt.show()
